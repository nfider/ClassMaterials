# %% [markdown]
# To start, select "Cell" in the toolbar... it is the 5th option, between "Insert" and "Kernel."
# Then choose "Run All."
# The first time you run the notebook may take a few minutes.

# %% [markdown]
# # MATH 3A: Building $\mathbb{R}^2$ vector intuition
#
# ## How to "read" a vector
#
# Remember that we can think of the vector $\mathbf{\overline{x}}$ as "instructions" telling us how to move from any start position.  For example, the vector $\mathbf{\overline{x}}=\begin{bmatrix}4\\6\end{bmatrix}$ tells us to move 4 to the right and 6 up (negative entries mean left/down).  Typically, we assume that our start position is the origin.
#
# ## How to "read" a linear combination
#
# Consider the linear combination
#
# $$\quad(5)\mathbf{\overline{u}}+(2)\mathbf{\overline{v}}+(-1)\mathbf{\overline{w}}$$
#
# and remember that we can think of each vector as a set of "instructions" telling us how to move from any start position.  So the vector $5\mathbf{\overline{u}}$, the vector $2\mathbf{\overline{v}}$, and the vector $-1\mathbf{\overline{w}}$ can each be thought of as an independent set of instructions.  The sum of those three vectors can be thought of a set of "stacked" instructions.  That is, we go through the following steps:
# - Starting from the origin, follow the instructions of $5\mathbf{\overline{u}}$.  This will lead you to a point $P_1$.
# - Starting from $P_1$ (the tail of the vector $5\mathbf{\overline{u}}$), follow the instructions of $2\mathbf{\overline{v}}$.  This will lead you to a point $P_2$.
# - Starting from $P_2$ (the tail of the vector $(5)\mathbf{\overline{u}}+(2)\mathbf{\overline{v}}$), follow the instructions in $-1\mathbf{\overline{w}}$.  This will lead you to the final point $P_3$.
#
# So following the "stacked" instructions in $(5)\mathbf{\overline{u}}+(2)\mathbf{\overline{v}}+(-1)\mathbf{\overline{w}}$ is equivalent to following the one vector that begins at the origin and ends at the point $P_3$.
#
# ## KEY DEFINITIONS
#
# <div class="alert alert-block alert-info">
# A vector $\mathbf{\overline{y}}\end{bmatrix}$ is a <b>linear combination</b> of the vectors $\mathbf{\overline{v}}_{1}, \mathbf{\overline{v}}_{2}, \dots, \mathbf{\overline{v}}_{p}$ if there are scalar weights $c_1, c_2, \dots, c_p$ such that
# $\mathbf{\overline{y}}=c_1\mathbf{\overline{v}}_{1}+c_2\mathbf{\overline{v}}_{2}+ \dots +c_p\mathbf{\overline{v}}_{p}$.</div>
#
# For convenience, you can say $\mathbf{\overline{y}}=\begin{bmatrix}y_1\\y_2\end{bmatrix}$ is a linear combination of the vectors $\mathbf{\overline{v}}_{1}, \mathbf{\overline{v}}_{2}, \dots, \mathbf{\overline{v}}_{p}$ if we can use scaled versions of the vectors to reach the point $(y_1, y_2)$.  So we can visualize the linear combination with a point instead of with vectors.
#
# <div class="alert alert-block alert-info">
# The collection of all possible linear combinations of the vectors $\mathbf{\overline{v}}_{1}, \mathbf{\overline{v}}_{2}, \dots, \mathbf{\overline{v}}_{p}$ is called <b>the span of $\mathbf{\overline{v}}_{1}, \mathbf{\overline{v}}_{2}, \dots, \mathbf{\overline{v}}_{p}$</b>; we denote it with the symbols $Span\{\mathbf{\overline{v}}_{1}, \mathbf{\overline{v}}_{2}, \dots, \mathbf{\overline{v}}_{p}\}$.</div>
#
# If we want to visualize the span of a collections of vectors, it is convenent to instead picture all possible points that can be reached using those vectors.
#
# ## How to make your own examples
#
# In class, we used the vectors $\mathbf{\overline{u}}=\begin{bmatrix}2\\-1\end{bmatrix}$, $\mathbf{\overline{v}}=\begin{bmatrix}6\\4\end{bmatrix}$, and $\mathbf{\overline{w}}=\begin{bmatrix}5\\0\end{bmatrix}$.  If you would like to use your own vectors, edit the entries of $\mathbf{\overline{u}}$ and/or $\mathbf{\overline{v}}$ and/or $\mathbf{\overline{w}}$ in the code cell immediaterly following this cell. The syntax for a vector in $\mathbb{R}^2$ in this programming language is `[x1,x2]`.
#
# Then select "Cell"$\rightarrow$"Run all" again (just like you did to run the notebook at the start).

# %%
u=[2,-1]
v=[6,4]
w=[5,0];

# %% [markdown]
# ## Preliminary example: plotting three vectors in $\mathbb{R}^2$
#
# Each vector is plotted in standard position.  For example, the vector $\mathbf{\overline{x}}=\begin{bmatrix}x_1\\x_2\end{bmatrix}$ starts at the origin and ends at the point $(x_1,x_2)$.

# %%
# Example
using Plots
plotly()

xu=[0,u[1]];
yu=[0,u[2]];
plot(xu,yu, title="Example: u,v,w", label='u', linecolor="red",lims=[-10,10])
scatter!([u[1], u[1]],[u[2],u[2]], markercolor="red", label="($(u[1]),$(u[2]))")
xv=[0,v[1]];
yv=[0,v[2]];
plot!(xv,yv, label='v', linecolor="purple")
scatter!([v[1],v[1]],[v[2],v[2]], markercolor="purple", label="($(v[1]),$(v[2]))")
xw=[0,w[1]];
yw=[0,w[2]];
plot!(xw,yw, label='w', linecolor="blue")
scatter!([w[1], w[1]],[w[2],w[2]], markercolor="blue", label="($(w[1]),$(w[2]))")
# Out:
#     <div id="8bfd6737-3888-47a7-8d8e-332f5a336e14" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('8bfd6737-3888-47a7-8d8e-332f5a336e14');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0,2],"showlegend":true,"mode":"lines","name":"u","zmin":-0.1,"legendgroup":"u","zmax":0.1,"line":{"color":"rgba(255, 0, 0, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0,-1],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[2,2],"showlegend":true,"mode":"markers","name":"(2,-1)","zmin":-0.1,"legendgroup":"(2,-1)","marker":{"symbol":"circle","color":"rgba(255, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[-1,-1],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0,6],"showlegend":true,"mode":"lines","name":"v","zmin":-0.1,"legendgroup":"v","zmax":0.1,"line":{"color":"rgba(128, 0, 128, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0,4],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[6,6],"showlegend":true,"mode":"markers","name":"(6,4)","zmin":-0.1,"legendgroup":"(6,4)","marker":{"symbol":"circle","color":"rgba(128, 0, 128, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[4,4],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0,5],"showlegend":true,"mode":"lines","name":"w","zmin":-0.1,"legendgroup":"w","zmax":0.1,"line":{"color":"rgba(0, 0, 255, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0,0],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[5,5],"showlegend":true,"mode":"markers","name":"(5,0)","zmin":-0.1,"legendgroup":"(5,0)","marker":{"symbol":"circle","color":"rgba(0, 0, 255, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[0,0],"type":"scatter","hoverinfo":"text"}], {"showlegend":true,"xaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[-10.0,-5.0,0.0,5.0,10.0],"visible":true,"ticks":"inside","range":[-10.6,10.6],"domain":[0.05100612423447069,0.9934383202099737],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["-10","-5","0","5","10"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"y1"},"paper_bgcolor":"rgba(255, 255, 255, 1.000)","annotations":[{"yanchor":"top","xanchor":"center","rotation":-0.0,"y":1.0,"font":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":20},"yref":"paper","showarrow":false,"text":"Example: u,v,w","xref":"paper","x":0.5222222222222223}],"height":400,"margin":{"l":0,"b":20,"r":0,"t":20},"plot_bgcolor":"rgba(255, 255, 255, 1.000)","yaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[-10.0,-5.0,0.0,5.0,10.0],"visible":true,"ticks":"inside","range":[-10.6,10.6],"domain":[0.03762029746281716,0.9415463692038496],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["-10","-5","0","5","10"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"x1"},"legend":{"tracegroupgap":0,"bordercolor":"rgba(0, 0, 0, 1.000)","bgcolor":"rgba(255, 255, 255, 1.000)","font":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"y":1.0,"x":1.0},"width":600});
#     </script>

# %% [markdown]
# ## Example 1a.  Plot possible linear combinations using three vectors in $\mathbb{R}^2$
#
# Here, random integer weights ($a_1,a_2$ and $a_3$) between -3 and 3 for the three vectors are chosen.
#
# To see a different randomly generated linear combination, select the following cell by single-clicking anywhere in the gray code area.  Then hit the "Run" button.

# %%
# Example 1a
using Plots
plotly()

u=[2,-1]; v=[6,4]; w=[5,0];


a1=rand(-5:5); a2=rand(-3:3); a3=rand(-3:3);
U=u*a1; V=v*a2; W=w*a3;

while abs(U[1]+V[1]+W[1])>20 || abs(U[2]+V[2]+W[2])>20
   a1=rand(-5:5)
    a2=rand(-3:3)
    a3=rand(-3:3)
    U=u*a1 
    V=v*a2
    W=w*a3 
end

xu=[0,U[1]];
yu=[0,U[2]];
plot(xu,yu, title="Example 1a: lin.combination of u,v,w", label="$a1 u", linecolor="red",lims=[-20,20])

xv=[U[1],U[1]+V[1]];
yv=[U[2],U[2]+V[2]];
plot!(xv,yv, linecolor="purple", label="$a2 v")

xw=[U[1]+V[1],U[1]+V[1]+W[1]];
yw=[U[2]+V[2],U[2]+V[2]+W[2]];
plot!(xw,yw, linecolor="blue", label="$a3 w")
scatter!([U[1]+V[1]+W[1], U[1]+V[1]+W[1]],[U[2]+V[2]+W[2],U[2]+V[2]+W[2]], markercolor="black", label="end point")
# Out:
#     <div id="b9230bdf-987c-4899-bf64-c72c4845001a" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('b9230bdf-987c-4899-bf64-c72c4845001a');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0,-4],"showlegend":true,"mode":"lines","name":"-2 u","zmin":-0.1,"legendgroup":"-2 u","zmax":0.1,"line":{"color":"rgba(255, 0, 0, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0,2],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-4,2],"showlegend":true,"mode":"lines","name":"1 v","zmin":-0.1,"legendgroup":"1 v","zmax":0.1,"line":{"color":"rgba(128, 0, 128, 1.000)","shape":"linear","dash":"solid","width":1},"y":[2,6],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[2,-13],"showlegend":true,"mode":"lines","name":"-3 w","zmin":-0.1,"legendgroup":"-3 w","zmax":0.1,"line":{"color":"rgba(0, 0, 255, 1.000)","shape":"linear","dash":"solid","width":1},"y":[6,6],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-13,-13],"showlegend":true,"mode":"markers","name":"end point","zmin":-0.1,"legendgroup":"end point","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[6,6],"type":"scatter","hoverinfo":"text"}], {"showlegend":true,"xaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[-20.0,-10.0,0.0,10.0,20.0],"visible":true,"ticks":"inside","range":[-21.2,21.2],"domain":[0.05100612423447069,0.9934383202099737],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["-20","-10","0","10","20"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"y1"},"paper_bgcolor":"rgba(255, 255, 255, 1.000)","annotations":[{"yanchor":"top","xanchor":"center","rotation":-0.0,"y":1.0,"font":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":20},"yref":"paper","showarrow":false,"text":"Example 1a: lin.combination of u,v,w","xref":"paper","x":0.5222222222222223}],"height":400,"margin":{"l":0,"b":20,"r":0,"t":20},"plot_bgcolor":"rgba(255, 255, 255, 1.000)","yaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[-20.0,-10.0,0.0,10.0,20.0],"visible":true,"ticks":"inside","range":[-21.2,21.2],"domain":[0.03762029746281716,0.9415463692038496],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["-20","-10","0","10","20"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"x1"},"legend":{"tracegroupgap":0,"bordercolor":"rgba(0, 0, 0, 1.000)","bgcolor":"rgba(255, 255, 255, 1.000)","font":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"y":1.0,"x":1.0},"width":600});
#     </script>

# %% [markdown]
# ## Example 1b.  Plot many possible linear combinations using three vectors in $\mathbb{R}^2$
#
# Here, random integer weights ($a_1,a_2$ and $a_3$) between -5 and 5 for the three vectors are chosen.  To simplify the picture, we only plot the final endpoint of each linear combination.

# %%
# Example 1b
using Plots
plotly()

u=[2,-1]; v=[6,4]; w=[5,0];
NumberOfPoints=800;

a1=rand(-5:5); a2=rand(-5:5); a3=rand(-5:5);
U=u*a1; V=v*a2; W=w*a3;

while abs(U[1]+V[1]+W[1])>20 || abs(U[2]+V[2]+W[2])>20
   a1=rand(-5:5)
    a2=rand(-5:5)
    a3=rand(-5:5)
    U=u*a1 
    V=v*a2
    W=w*a3 
    
end
p=plot(title="Example 1b: Span{u,v,w}", legend=false)
scatter!([U[1]+V[1]+W[1], U[1]+V[1]+W[1]],[U[2]+V[2]+W[2],U[2]+V[2]+W[2]], markercolor="black", label="end point",lims=[-20,20])

if NumberOfPoints>1
    for n = 2:NumberOfPoints
        a1=rand(-5:5); a2=rand(-5:5); a3=rand(-5:5);
        U=u*a1; V=v*a2; W=w*a3;
        while abs(U[1]+V[1]+W[1])>20 || abs(U[2]+V[2]+W[2])>20
            a1=rand(-5:5)
            a2=rand(-5:5)
            a3=rand(-5:5)
            U=u*a1 
            V=v*a2
            W=w*a3 
        end
        scatter!([U[1]+V[1]+W[1], U[1]+V[1]+W[1]],[U[2]+V[2]+W[2],U[2]+V[2]+W[2]], markercolor="black", label="end point")
    end
end
display(p)
# Out:
#     <div id="e292601c-a3be-413c-ab3d-a268e7b11f6c" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('e292601c-a3be-413c-ab3d-a268e7b11f6c');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[20,20],"showlegend":true,"mode":"markers","name":"end point","zmin":-0.1,"legendgroup":"end point","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[4,4],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-19,-19],"showlegend":true,"mode":"markers","name":"end point","zmin":-0.1,"legendgroup":"end point","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[0,0],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[8,8],"showlegend":true,"mode":"markers","name":"end point","zmin":-0.1,"legendgroup":"end point","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[19,19],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-10,-10],"showlegend":true,"mode":"markers","name":"end point","zmin":-0.1,"legendgroup":"end point","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[-11,-11],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-8,-8],"showlegend":true,"mode":"markers","name":"end point","zmin":-0.1,"legendgroup":"end point","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[1,1],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-14,-14],"showlegend":true,"mode":"markers","name":"end point","zmin":-0.1,"legendgroup":"end point","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[-16,-16],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[20,20],"showlegend":true,"mode":"markers","name":"end point","zmin":-0.1,"legendgroup":"end point","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[0,0],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[13,13],"showlegend":true,"mode":"markers","name":"end point","zmin":-0.1,"legendgroup":"end point","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[8,8],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[5,5],"showlegend":true,"mode":"markers","name":"end point","zmin":-0.1,"legendgroup":"end point","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[16,16],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-1,-1],"showlegend":true,"mode":"markers","name":"end point","zmin":-0.1,"legendgroup":"end point","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[-4,-4],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[16,16],"showlegend":true,"mode":"markers","name":"end point","zmin":-0.1,"legendgroup":"end point","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[17,17],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[2,2],"showlegend":true, ...

# %% [markdown]
# ## Example 2a.  Plot a possible linear combination using two vectors in $\mathbb{R}^2$
#
# Here, random integer weights ($a_1$ and $a_2$) between -5 and 5 for the two vectors are chosen.
#
# To see a different randomly generated linear combination, select the following cell by single-clicking anywhere in the gray code area.  Then hit the "Run" button.

# %%
# Example 2a
using Plots
plotly()

u=[2,-1]; v=[6,4]; 


a1=rand(-5:5); a2=rand(-5:5);
U=u*a1; V=v*a2; 

while abs(U[1]+V[1])>20 || abs(U[2]+V[2])>20
   a1=rand(-5:5)
    a2=rand(-5:5)
    U=u*a1 
    V=v*a2

end

xu=[0,U[1]];
yu=[0,U[2]];
plot(xu,yu, title="Example 2a: lin.combinations of u,v", label="$a1 u", linecolor="red",lims=[-20,20])

xv=[U[1],U[1]+V[1]];
yv=[U[2],U[2]+V[2]];
plot!(xv,yv, linecolor="purple", label="$a2 v")

scatter!([U[1]+V[1], U[1]+V[1]],[U[2]+V[2],U[2]+V[2]], markercolor="black", label="end point")
# Out:
#     <div id="a018211e-2f18-4c26-93cd-3e928a21e21d" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('a018211e-2f18-4c26-93cd-3e928a21e21d');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0,0],"showlegend":true,"mode":"lines","name":"0 u","zmin":-0.1,"legendgroup":"0 u","zmax":0.1,"line":{"color":"rgba(255, 0, 0, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0,0],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0,0],"showlegend":true,"mode":"lines","name":"0 v","zmin":-0.1,"legendgroup":"0 v","zmax":0.1,"line":{"color":"rgba(128, 0, 128, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0,0],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0,0],"showlegend":true,"mode":"markers","name":"end point","zmin":-0.1,"legendgroup":"end point","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[0,0],"type":"scatter","hoverinfo":"text"}], {"showlegend":true,"xaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[-20.0,-10.0,0.0,10.0,20.0],"visible":true,"ticks":"inside","range":[-21.2,21.2],"domain":[0.05100612423447069,0.9934383202099737],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["-20","-10","0","10","20"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"y1"},"paper_bgcolor":"rgba(255, 255, 255, 1.000)","annotations":[{"yanchor":"top","xanchor":"center","rotation":-0.0,"y":1.0,"font":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":20},"yref":"paper","showarrow":false,"text":"Example 2a: lin.combinations of u,v","xref":"paper","x":0.5222222222222223}],"height":400,"margin":{"l":0,"b":20,"r":0,"t":20},"plot_bgcolor":"rgba(255, 255, 255, 1.000)","yaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[-20.0,-10.0,0.0,10.0,20.0],"visible":true,"ticks":"inside","range":[-21.2,21.2],"domain":[0.03762029746281716,0.9415463692038496],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["-20","-10","0","10","20"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"x1"},"legend":{"tracegroupgap":0,"bordercolor":"rgba(0, 0, 0, 1.000)","bgcolor":"rgba(255, 255, 255, 1.000)","font":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"y":1.0,"x":1.0},"width":600});
#     </script>

# %% [markdown]
# ## Example 2b.  Plot many possible linear combinations using two vectors in $\mathbb{R}^2$
#
# Here, random integer weights ($a_1$ and $a_2$) between -20 and 20 for the two vectors are chosen.

# %%
# Example 2b
using Plots
plotly()

u=[2,-1]; v=[6,4]
NumberOfPoints=500;

a1=rand(-20:20)*rand(); a2=rand(-20:20)*rand()
U=u*a1; V=v*a2;

while abs(U[1]+V[1])>20 || abs(U[2]+V[2])>20
   a1=rand(-20:20)*rand()
    a2=rand(-20:20)*rand()
    U=u*a1 
    V=v*a2
    
end
p=plot(title="Example 2b: Span{u,v}", legend=false)
scatter!([U[1]+V[1], U[1]+V[1]],[U[2]+V[2],U[2]+V[2]], markercolor="black",lims=[-20,20])

if NumberOfPoints>1
    for n = 2:NumberOfPoints
        a1=rand(-20:20)*rand(); a2=rand(-20:20)*rand()
        U=u*a1; V=v*a2; 
        while abs(U[1]+V[1])>20 || abs(U[2]+V[2])>20
            a1=rand(-20:20)*rand()
            a2=rand(-20:20)*rand()
            U=u*a1 
            V=v*a2
        end
        scatter!([U[1]+V[1], U[1]+V[1]],[U[2]+V[2],U[2]+V[2]], markercolor="black")
    end
end
display(p)
# Out:
#     <div id="80983a69-4f49-45fa-85b3-34529e8c9d64" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('80983a69-4f49-45fa-85b3-34529e8c9d64');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-11.711053083129219,-11.711053083129219],"showlegend":true,"mode":"markers","name":"y1","zmin":-0.1,"legendgroup":"y1","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[2.557067805152455,2.557067805152455],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-5.419895220713542,-5.419895220713542],"showlegend":true,"mode":"markers","name":"y2","zmin":-0.1,"legendgroup":"y2","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[-2.200171357142453,-2.200171357142453],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-2.508679968025919,-2.508679968025919],"showlegend":true,"mode":"markers","name":"y3","zmin":-0.1,"legendgroup":"y3","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[2.1861038319559447,2.1861038319559447],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[8.532235564685621,8.532235564685621],"showlegend":true,"mode":"markers","name":"y4","zmin":-0.1,"legendgroup":"y4","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[14.700903602958444,14.700903602958444],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-18.69061603514589,-18.69061603514589],"showlegend":true,"mode":"markers","name":"y5","zmin":-0.1,"legendgroup":"y5","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[-16.196921015449178,-16.196921015449178],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-0.6693350881007465,-0.6693350881007465],"showlegend":true,"mode":"markers","name":"y6","zmin":-0.1,"legendgroup":"y6","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[15.88077364230613,15.88077364230613],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-19.49732548414724,-19.49732548414724],"showlegend":true,"mode":"markers","name":"y7","zmin":-0.1,"legendgroup":"y7","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[-7.885829733594759,-7.885829733594759],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-7.153317391256563,-7.153317391256563],"showlegend":true,"mode":"markers","name":"y8","zmin":-0.1,"legendgroup":"y8","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[5.3242202875178535,5.3242202875178535],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[4.953768490064922,4.953768490064922],"showlegend":true,"mode":"markers","name":"y9","zmin":-0.1,"legendgroup":"y9","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[7.949370695700828,7.949370695700828],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[9.95466570867585,9.95466570867585],"showlegend":true,"mode":"markers","name":"y10","zmin":-0.1,"legendgroup":"y10","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[17.853402059842757,17.8534020 ...

# %% [markdown]
# ## Example 3a.  Plot a possible linear combination using one vector in $\mathbb{R}^2$
#
# Here, a random integer ($a_1$) between -20 and 20 is used as a weight for the vector.
#
# NOTE: a "linear combination" of a single vector is simply a "multiple" of that vector!!!
#
# To see a different randomly generated linear combination, select the following cell by single-clicking anywhere in the gray code area.  Then hit the "Run" button.

# %%
# Example 3a
using Plots
plotly()

u=[2,-1];


a1=rand(-20:20); 
U=u*a1; 

while abs(U[1])>20 || abs(U[2])>20
   a1=rand(-20:20); 
    U=u*a1 
end


xu=[0,U[1]];
yu=[0,U[2]];
plot(xu,yu, title="Example 3a: lin.combinations of u", label="$a1 u", linecolor="red",lims=[-20,20])

scatter!([U[1], U[1]],[U[2],U[2]], markercolor="black", label="end point")
# Out:
#     <div id="e127e6aa-742f-43ed-a1db-d9cc6eed34fe" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('e127e6aa-742f-43ed-a1db-d9cc6eed34fe');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0,-10],"showlegend":true,"mode":"lines","name":"-5 u","zmin":-0.1,"legendgroup":"-5 u","zmax":0.1,"line":{"color":"rgba(255, 0, 0, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0,5],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-10,-10],"showlegend":true,"mode":"markers","name":"end point","zmin":-0.1,"legendgroup":"end point","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[5,5],"type":"scatter","hoverinfo":"text"}], {"showlegend":true,"xaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[-20.0,-10.0,0.0,10.0,20.0],"visible":true,"ticks":"inside","range":[-21.2,21.2],"domain":[0.05100612423447069,0.9934383202099737],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["-20","-10","0","10","20"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"y1"},"paper_bgcolor":"rgba(255, 255, 255, 1.000)","annotations":[{"yanchor":"top","xanchor":"center","rotation":-0.0,"y":1.0,"font":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":20},"yref":"paper","showarrow":false,"text":"Example 3a: lin.combinations of u","xref":"paper","x":0.5222222222222223}],"height":400,"margin":{"l":0,"b":20,"r":0,"t":20},"plot_bgcolor":"rgba(255, 255, 255, 1.000)","yaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[-20.0,-10.0,0.0,10.0,20.0],"visible":true,"ticks":"inside","range":[-21.2,21.2],"domain":[0.03762029746281716,0.9415463692038496],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["-20","-10","0","10","20"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"x1"},"legend":{"tracegroupgap":0,"bordercolor":"rgba(0, 0, 0, 1.000)","bgcolor":"rgba(255, 255, 255, 1.000)","font":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"y":1.0,"x":1.0},"width":600});
#     </script>

# %% [markdown]
# ## Example 3b.  Plot many possible linear combinations using one vector in $\mathbb{R}^2$
#
# For each linear combination, a random integer ($a_1$) between -20 and 20 is used as a weight for the vector.
#
# NOTE: a "linear combination" of a single vector is simply a "multiple" of that vector!!!

# %%
# Example 3b
using Plots
plotly()

u=[2,-1];
NumberOfPoints=300;


a1=rand(-20:20)*rand(); 
U=u*a1; 

while abs(U[1])>20 || abs(U[2])>20
   a1=rand(-20:20)*rand(); 
    U=u*a1 
end


p=plot(title="Example 3b: Span{u}",lims=[-20,20], legend=false)

scatter!([U[1], U[1]],[U[2],U[2]], markercolor="black")

if NumberOfPoints>1
    for n = 2:NumberOfPoints
        a1=rand(-20:20)*rand(); 
        U=u*a1;
        while abs(U[1])>20 || abs(U[2])>20
            a1=rand(-20:20)*rand()
            U=u*a1 
        end
        scatter!([U[1], U[1]],[U[2],U[2]], markercolor="black")
    end
end
display(p)
# Out:
#     <div id="14110831-7fae-4eae-98b5-0e1d36687390" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('14110831-7fae-4eae-98b5-0e1d36687390');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[9.21442335497322,9.21442335497322],"showlegend":true,"mode":"markers","name":"y1","zmin":-0.1,"legendgroup":"y1","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[-4.60721167748661,-4.60721167748661],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[11.167586049724704,11.167586049724704],"showlegend":true,"mode":"markers","name":"y2","zmin":-0.1,"legendgroup":"y2","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[-5.583793024862352,-5.583793024862352],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-8.108962638606744,-8.108962638606744],"showlegend":true,"mode":"markers","name":"y3","zmin":-0.1,"legendgroup":"y3","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[4.054481319303372,4.054481319303372],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-15.705906326209607,-15.705906326209607],"showlegend":true,"mode":"markers","name":"y4","zmin":-0.1,"legendgroup":"y4","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[7.852953163104804,7.852953163104804],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[6.551994205776662,6.551994205776662],"showlegend":true,"mode":"markers","name":"y5","zmin":-0.1,"legendgroup":"y5","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[-3.275997102888331,-3.275997102888331],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-5.024088634297428,-5.024088634297428],"showlegend":true,"mode":"markers","name":"y6","zmin":-0.1,"legendgroup":"y6","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[2.512044317148714,2.512044317148714],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[3.6121071552628674,3.6121071552628674],"showlegend":true,"mode":"markers","name":"y7","zmin":-0.1,"legendgroup":"y7","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[-1.8060535776314337,-1.8060535776314337],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[8.299433801806728,8.299433801806728],"showlegend":true,"mode":"markers","name":"y8","zmin":-0.1,"legendgroup":"y8","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[-4.149716900903364,-4.149716900903364],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[-12.975793092462533,-12.975793092462533],"showlegend":true,"mode":"markers","name":"y9","zmin":-0.1,"legendgroup":"y9","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[6.4878965462312665,6.4878965462312665],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[8.452148655742825,8.452148655742825],"showlegend":true,"mode":"markers","name":"y10","zmin":-0.1,"legendgroup":"y10","marker":{"symbol":"circle","color":"rgba(0, 0, 0, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[-4.226074327871412,-4.22607432787 ...

# %% [markdown]
# # Conclusion
#
# In general, the span of vectors in $\mathbb{R}^2$ will be one of the following:
# - only the point $(0,0)$
# - a line through the origin
# - all of $R^2$ ($\leftarrow$ a plane through the origin)
#
# ## Follow up questions:
# Try to play around with some other vectors and see if you can answer these :)
# 1. What vector(s) do you need to have in the set for the span to ONLY be the origin?
# 2. Under what conditions will the span be a line?
# 3. Under what conditions will the span be all of $\mathbb{R}^2$?
# 4. Why does the span of a set of vectors always pass through the origin?
